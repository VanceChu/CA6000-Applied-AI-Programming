# %%
import pandas as pd
rental_data = pd.read_csv("../datasets/rental.csv")
rental_data
# Out:
#     Condo  Rental  Room
# 0       1    1000     1
# 1       1    1200     1
# 2       1    1500     1
# 3       1    2000     2
# 4       1    2400     2
# 5       1    2700     2
# 6       1    3300     2
# 7       1    3500     3
# 8       1    3800     3
# 9       1    4000     3
# 10      1    4500     3
# 11      1    4800     4
# 12      1    5000     4
# 13      1    5500     4
# 14      2     800     1
# 15      2    1000     1
# 16      2    1300     1
# 17      2    1500     2
# 18      2    2000     2
# 19      2    2200     2
# 20      2    3000     2
# 21      2    3300     3
# 22      2    3600     3
# 23      2    3800     3
# 24      2    4300     3
# 25      2    4600     4
# 26      2    4800     4
# 27      2    5300     4
